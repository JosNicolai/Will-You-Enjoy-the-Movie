# %%
import pandas as pd
import numpy as np
from imdb import Cinemagoer
from tqdm.auto import tqdm
import re

# %% [markdown]
# # Read movie dataset

# %%
df = pd.read_csv("Movies to watch - Ratings.csv")
df = df.iloc[1:,[0,1,2,3,4,5,6]]
df = df.rename(columns={'Unnamed: 0': "Film", "Unnamed: 11": "Average rating"})
df = df.replace("DNF", np.nan)
df
# Out:
#                   Film   Seb   Jos Coen Stijn  Merle   Twan
# 1            Inception   8.0  8.25  NaN   8.3  8.000    NaN
# 2    Good Will Hunting   9.0  9.00  NaN   9.1    NaN    NaN
# 3   Cabin in the Woods   7.0  7.00  6.5   4.6  8.300    NaN
# 4     Independence Day   7.0  7.20    7   3.7  6.900    NaN
# 5            Spotlight  10.0  8.80  8.5   7.7    NaN    NaN
# ..                 ...   ...   ...  ...   ...    ...    ...
# 80     American Psycho   8.0  7.00  4.5  9.32    NaN  7.496
# 81   Shaun of the Dead   7.5  8.00  6.5  7.87  7.545    NaN
# 82             Silence   9.0  7.60  6.4  6.09    NaN    NaN
# 83             Arrival   7.5  9.00  8.2  7.34    NaN    NaN
# 84           High Noon   4.0  5.00  NaN  2.19    NaN    NaN
#
# [84 rows x 7 columns]

# %% [markdown]
# # Download information from IMDB

# %%
# select interesting information from the following list:
# ['akas', 'animation department', 'art department', 'art direction', 'aspect ratio', 'assistant director', 'box office', 'camera and electrical department', 'canonical title', 'cast', 
#  'casting department', 'casting director', 'certificates', 'cinematographer', 'color info', 'composer', 'costume department', 'costume designer', 'countries', 'country codes', 
#  'cover url', 'director', 'distributors', 'editor', 'editorial department', 'full-size cover url', 'genres', 'imdbID', 'kind', 'language codes', 'languages', 'localized title', 
#  'location management', 'long imdb canonical title', 'long imdb title', 'make up', 'miscellaneous crew', 'music department', 'original air date', 'original title', 'other companies', 
#  'plot', 'plot outline', 'producer', 'production companies', 'production design', 'production manager', 'rating', 'runtimes', 'script department', 'set decoration', 'smart canonical title', 
#  'smart long imdb canonical title', 'sound crew', 'sound mix', 'special effects', 'special effects companies', 'stunt performer', 'synopsis', 'title', 'transportation department', 'visual effects', 
#  'votes', 'writer', 'year']

interesting_stats = ['aspect ratio', 'box office', 'director', 'genres', 'year', 'rating', 'votes', 'plot']

# %%
def retrieve_movie_stats(movie, interesting_stats, ia):    
    res = {}
    # searching the name 
    search = ia.search_movie(movie)
    
    # getting the id
    id = search[0].movieID
    
    # get a movie's info
    movie_info = ia.get_movie(id)
    
    for key in interesting_stats:
        try:
            if key in movie_info:
                if key == "box office":
                    res["Budget"] = movie_info[key]["Budget"]
                    if "Cumulative Worldwide Gross" in movie_info[key]: res["Cumulative Worldwide Gross"] = movie_info[key]["Cumulative Worldwide Gross"]
                elif key == "synopsis":
                    res[key] = movie_info[key][0]
                else:                
                #     if isinstance(movie_info[key], list):
                #         res[key] = ",".join(movie_info[key])
                #     else:                    
                    res[key] = str(movie_info[key])
            else:
                res[key] = np.nan
        except:
            res[key] = np.nan
        
    return res

# %%
# create an instance of the Cinemagoer class
cnm = Cinemagoer()

# list interesting columns
interesting_stats = ['aspect ratio', 'box office', 'director', 'genres', 'year', 'rating', 'votes', 'synopsis']
movie_stats = {}
for movie in df.Film.values:
    movie_stats[movie] = retrieve_movie_stats(movie, interesting_stats, cnm)
    
movie_stats = pd.DataFrame.from_dict(movie_stats, orient="index")
movie_stats.to_csv("movie_stats.csv")
movie_stats
# Out:
#                                      aspect ratio                    Budget  \
# Inception                                2.39 : 1  $160,000,000 (estimated)
# Good Will Hunting                        1.85 : 1   $10,000,000 (estimated)
# Cabin in the Woods                            NaN        $3,000 (estimated)
# Independence Day           2.20 : 1 (70 mm print)   $75,000,000 (estimated)
# Spotlight                                1.85 : 1   $20,000,000 (estimated)
# ...                                           ...                       ...
# American Psycho     1.78 : 1 (open matte Blu-ray)    $7,000,000 (estimated)
# Shaun of the Dead       1.78 : 1 (negative ratio)  GBP4,000,000 (estimated)
# Silence                                  2.39 : 1   $46,000,000 (estimated)
# Arrival                                  2.39 : 1   $47,000,000 (estimated)
# High Noon                                1.37 : 1      $730,000 (estimated)
#
#                    Cumulative Worldwide Gross  \
# Inception           $825,532,764, 06 Jan 2011
# Good Will Hunting                $225,933,435
# Cabin in the Woods                        NaN
# Independence Day                          NaN
# Spotlight                         $98,275,238
# ...                                       ...
# American Psycho                   $34,266,564
# Shaun of the Dead                 $30,039,392
# Silence                           $23,737,523
# Arrival                          $203,388,186
# High Noon                                 NaN
#
#                                                              director  \
# Inception           [<Person id:0634240[http] name:_Christopher No...
# Good Will Hunting     [<Person id:0001814[http] name:_Gus Van Sant_>]
# Cabin in the Woods    [<Person id:5981437[http] name:_Kyla Jarrett_>]
# Independence Day    [<Person id:0000386[http] name:_Roland Emmeric...
# Spotlight             [<Person id:0565336[http] name:_Tom McCarthy_>]
# ...                                                               ...
# American Psycho        [<Person id:0366004[http] name:_Mary Harron_>]
# Shaun of the Dead     [<Person id:0942367[http] name:_Edgar Wright_>]
# Silence             [<Person id:0000217[http] name:_Martin Scorses...
# Arrival             [<Person id:0898288[http] name:_Denis Villeneu...
# High Noon           [<Person id:0003593[http] name:_Fred Zinnemann_>]
#
#                                                            genres  year  \
# Inception           ['Action', 'Adventure', 'Sci-Fi', 'Thriller']  2010
# Good Will Hunting                            ['Drama', 'Romance']  1997
# Cabin in the Woods                             ['Short', 'Drama']   NaN
# Independence Day                ['Action', 'Adventure', 'Sci-Fi']  1996
# Spotlight                         ['Biography', 'Crime', 'Drama']  2015
# ...                                                           ...   ...
# American Psycho                      ['Crime', 'Drama', 'Horror']  2000
# Shaun of the Dead                            ['Comedy', 'Horror']  2004
# Silence                                      ['Drama', 'History']  2016
# Arrival                            ['Drama', 'Mystery', 'Sci-Fi']  2016
# High Noon                        ['Drama', 'Thriller', 'Western']  1952
#
#                    rating    votes  \
# Inception             8.8  2315131
# Good Will Hunting     8.3   954678
# Cabin in the Woods    NaN      NaN
# Independence Day      7.0   572816
# Spotlight             8.1   466101
# ...                   ...      ...
# American Psycho       7.6   596510
# Shaun of the Dead     7.9   554306
# Silence               7.1   112784
# Arrival               7.9   683982
# High Noon             8.0   104237
#
#                                                              synopsis  \
# Inception           A young man, exhausted and delirious, washes u...
# Good Will Hunting   Though Will Hunting (Matt Damon) has genius-le...
# Cabin in the Woods                                                NaN
# Independence Day    On July 2, a giant alien mother ship, over 340...
# Spotlight           The opening shot shows the text: BASED ON ACTU...
# ...                                                               ...
# American Psycho     A white background. Red drops begin to fall pa...
# Shaun of the Dead   The film begins in The Winchester, a tradition...
# Silence             Over darkness, environmental sounds (crickets ...
# Arrival             The film starts with the voice of Dr. Louise B...
# High Noon           The movie opens with outlaws Jack Colby (Lee V...
#
#                     box office
# Inception                  NaN
# Good Will Hunting          NaN
# Cabin in the Woods         NaN
# Independence Day           NaN
# Spotlight                  NaN
# ...                        ...
# American Psycho            NaN
# Shaun of the Dead          NaN
# Silence                    NaN
# Arrival                    NaN
# High Noon                  NaN
#
# [84 rows x 10 columns]

# %% [markdown]
# # Process data

# %% [markdown]
# ## Budget

# %%
movie_stats = pd.read_csv("movie_stats.csv")

# %%
def process_budget(x):
    # print(x["Budget"])
    x = re.findall("\d{1,3},{0,1}\d{1,3},{0,1}\d{1,3}", str(x))
    if x == []: return float(np.nan)
    else: return float(x[0].replace(",", ""))
    
movie_stats["Budget"] = movie_stats["Budget"].apply(process_budget)

# %% [markdown]
# ## Gross

# %%
movie_stats["Cumulative Worldwide Gross"] = movie_stats["Cumulative Worldwide Gross"].apply(process_budget)

# %% [markdown]
# ## genres

# %%
# first get a list of all unique categories and also keep the list of categories per movie
all_movie_cats = []
unique_categories = []
for s in movie_stats["genres"].values:
    s = s.replace(" ", "")
    s = s.replace("'", "")
    s = s.replace("[", "")
    s = s.replace("]", "")
    movie_cats = s.split(",")
    all_movie_cats.append(movie_cats)
    for i in movie_cats:
        if i not in unique_categories:
            unique_categories.append(i)
unique_categories
# Out:
# ['Action',
#  'Adventure',
#  'Sci-Fi',
#  'Thriller',
#  'Drama',
#  'Romance',
#  'Short',
#  'Biography',
#  'Crime',
#  'History',
#  'War',
#  'Western',
#  'Talk-Show',
#  'Animation',
#  'Comedy',
#  'Fantasy',
#  'Music',
#  'Family',
#  'Sport',
#  'Mystery',
#  'Horror',
#  'Documentary',
#  'Musical']

# %%
len(movie_stats.iloc[:,0])
# Out:
# 84

# %%
genre_matrix = {}
# now create a column for every genre with a True of False depending on wheter a movie has a certain genre
for i in range(len(all_movie_cats)):
    movie = movie_stats.iloc[:,0].values[i]
    d = {}
    for genre in unique_categories:
        if genre in all_movie_cats[i]:
            d[genre] = True 
        else:
            d[genre] = False 
    genre_matrix[movie] = d
    #movie_stats.iloc[:,0]
genre_matrix = pd.DataFrame.from_dict(genre_matrix, orient="index").reset_index()
genre_matrix
# Out:
#                  index  Action  Adventure  Sci-Fi  Thriller  Drama  Romance  \
# 0            Inception    True       True    True      True  False    False
# 1    Good Will Hunting   False      False   False     False   True     True
# 2   Cabin in the Woods   False      False   False     False   True    False
# 3     Independence Day    True       True    True     False  False    False
# 4            Spotlight   False      False   False     False   True    False
# ..                 ...     ...        ...     ...       ...    ...      ...
# 79     American Psycho   False      False   False     False   True    False
# 80   Shaun of the Dead   False      False   False     False  False    False
# 81             Silence   False      False   False     False   True    False
# 82             Arrival   False      False    True     False   True    False
# 83           High Noon   False      False   False      True   True    False
#
#     Short  Biography  Crime  ...  Animation  Comedy  Fantasy  Music  Family  \
# 0   False      False  False  ...      False   False    False  False   False
# 1   False      False  False  ...      False   False    False  False   False
# 2    True      False  False  ...      False   False    False  False   False
# 3   False      False  False  ...      False   False    False  False   False
# 4   False       True   True  ...      False   False    False  False   False
# ..    ...        ...    ...  ...        ...     ...      ...    ...     ...
# 79  False      False   True  ...      False   False    False  False   False
# 80  False      False  False  ...      False    True    False  False   False
# 81  False      False  False  ...      False   False    False  False   False
# 82  False      False  False  ...      False   False    False  False   False
# 83  False      False  False  ...      False   False    False  False   False
#
#     Sport  Mystery  Horror  Documentary  Musical
# 0   False    False   False        False    False
# 1   False    False   False        False    False
# 2   False    False   False        False    False
# 3   False    False   False        False    False
# 4   False    False   False        False    False
# ..    ...      ...     ...          ...      ...
# 79  False    False    True        False    False
# 80  False    False    True        False    False
# 81  False    False   False        False    False
# 82  False     True   False        False    False
# 83  False    False   False        False    False
#
# [84 rows x 24 columns]

# %%
pd.merge(df, movie_stats[columns_to_keep], left_on="Film", right_on="Unnamed: 0").drop("Unnamed: 0", axis=1)
# Out:
#                   Film   Seb   Jos Coen Stijn  Merle   Twan       Budget  \
# 0            Inception   8.0  8.25  NaN   8.3  8.000    NaN  160000000.0
# 1    Good Will Hunting   9.0  9.00  NaN   9.1    NaN    NaN   10000000.0
# 2   Cabin in the Woods   7.0  7.00  6.5   4.6  8.300    NaN       3000.0
# 3     Independence Day   7.0  7.20    7   3.7  6.900    NaN   75000000.0
# 4            Spotlight  10.0  8.80  8.5   7.7    NaN    NaN   20000000.0
# ..                 ...   ...   ...  ...   ...    ...    ...          ...
# 79     American Psycho   8.0  7.00  4.5  9.32    NaN  7.496    7000000.0
# 80   Shaun of the Dead   7.5  8.00  6.5  7.87  7.545    NaN    4000000.0
# 81             Silence   9.0  7.60  6.4  6.09    NaN    NaN   46000000.0
# 82             Arrival   7.5  9.00  8.2  7.34    NaN    NaN   47000000.0
# 83           High Noon   4.0  5.00  NaN  2.19    NaN    NaN     730000.0
#
#     Cumulative Worldwide Gross    year  rating      votes  \
# 0                  825532764.0  2010.0     8.8  2315131.0
# 1                  225933435.0  1997.0     8.3   954678.0
# 2                          NaN     NaN     NaN        NaN
# 3                          NaN  1996.0     7.0   572816.0
# 4                   98275238.0  2015.0     8.1   466101.0
# ..                         ...     ...     ...        ...
# 79                  34266564.0  2000.0     7.6   596510.0
# 80                  30039392.0  2004.0     7.9   554306.0
# 81                  23737523.0  2016.0     7.1   112784.0
# 82                 203388186.0  2016.0     7.9   683982.0
# 83                         NaN  1952.0     8.0   104237.0
#
#                                              synopsis
# 0   A young man, exhausted and delirious, washes u...
# 1   Though Will Hunting (Matt Damon) has genius-le...
# 2                                                 NaN
# 3   On July 2, a giant alien mother ship, over 340...
# 4   The opening shot shows the text: BASED ON ACTU...
# ..                                                ...
# 79  A white background. Red drops begin to fall pa...
# 80  The film begins in The Winchester, a tradition...
# 81  Over darkness, environmental sounds (crickets ...
# 82  The film starts with the voice of Dr. Louise B...
# 83  The movie opens with outlaws Jack Colby (Lee V...
#
# [84 rows x 13 columns]

# %%
columns_to_keep = ["Unnamed: 0", "Budget", "Cumulative Worldwide Gross", "year", "rating", "votes", "synopsis" ]
clean_df = pd.merge(df, movie_stats[columns_to_keep], left_on="Film", right_on="Unnamed: 0").drop("Unnamed: 0", axis=1)
clean_df = pd.merge(clean_df, genre_matrix, left_on="Film", right_on="index").drop("index", axis=1)
clean_df.to_csv("clean_df.csv")
clean_df
# Out:
#                   Film   Seb   Jos Coen Stijn  Merle   Twan       Budget  \
# 0            Inception   8.0  8.25  NaN   8.3  8.000    NaN  160000000.0
# 1    Good Will Hunting   9.0  9.00  NaN   9.1    NaN    NaN   10000000.0
# 2   Cabin in the Woods   7.0  7.00  6.5   4.6  8.300    NaN       3000.0
# 3     Independence Day   7.0  7.20    7   3.7  6.900    NaN   75000000.0
# 4            Spotlight  10.0  8.80  8.5   7.7    NaN    NaN   20000000.0
# ..                 ...   ...   ...  ...   ...    ...    ...          ...
# 79     American Psycho   8.0  7.00  4.5  9.32    NaN  7.496    7000000.0
# 80   Shaun of the Dead   7.5  8.00  6.5  7.87  7.545    NaN    4000000.0
# 81             Silence   9.0  7.60  6.4  6.09    NaN    NaN   46000000.0
# 82             Arrival   7.5  9.00  8.2  7.34    NaN    NaN   47000000.0
# 83           High Noon   4.0  5.00  NaN  2.19    NaN    NaN     730000.0
#
#     Cumulative Worldwide Gross    year  ...  Animation  Comedy Fantasy  Music  \
# 0                  825532764.0  2010.0  ...      False   False   False  False
# 1                  225933435.0  1997.0  ...      False   False   False  False
# 2                          NaN     NaN  ...      False   False   False  False
# 3                          NaN  1996.0  ...      False   False   False  False
# 4                   98275238.0  2015.0  ...      False   False   False  False
# ..                         ...     ...  ...        ...     ...     ...    ...
# 79                  34266564.0  2000.0  ...      False   False   False  False
# 80                  30039392.0  2004.0  ...      False    True   False  False
# 81                  23737523.0  2016.0  ...      False   False   False  False
# 82                 203388186.0  2016.0  ...      False   False   False  False
# 83                         NaN  1952.0  ...      False   False   False  False
#
#     Family  Sport  Mystery  Horror  Documentary  Musical
# 0    False  False    False   False        False    False
# 1    False  False    False   False        False    False
# 2    False  False    False   False        False    False
# 3    False  False    False   False        False    False
# 4    False  False    False   False        False    False
# ..     ...    ...      ...     ...          ...      ...
# 79   False  False    False    True        False    False
# 80   False  False    False    True        False    False
# 81   False  False    False   False        False    False
# 82   False  False     True   False        False    False
# 83   False  False    False   False        False    False
#
# [84 rows x 36 columns]
